# %% [markdown]
# # Display the final Results after analysis

# %%
from analysis import run_analysis_by_name, get_all_errors
from models import BaseModel, BaseExtModel
#%matplotlib notebook

# %% [markdown]
# ## Analyse a file one by one:

# %%
filename = 'F1Gang3'
run_analysis_by_name(filename, movie=False)
# Out:
# DELTA: -57
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/biomech/Documents/movementdata/src/_main.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bhyrican/home/biomech/Documents/movementdata/src/_main.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> filename = 'F1Gang3'
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhyrican/home/biomech/Documents/movementdata/src/_main.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> run_analysis_by_name(filename, movie=False)
#
# File ~/Documents/movementdata/src/analysis.py:679, in run_analysis_by_name(file, movie)
#     676 plot_angle(basemodel.get_knee_angles, 'knee', data, file, lr=1)
#     677 mse_dec, mse_imu = calc_mse_angle(basemodel, data)
# --> 679 print(f'DEC-Err: {round(mse_dec[0], 2)}° ± {round(mse_dec[1], 2)}°')
# ...

# %% [markdown]
# ## Run Analysis over all files:

# %%
get_all_errors(save=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/biomech/Documents/movementdata/src/_main.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bhyrican/home/biomech/Documents/movementdata/src/_main.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> get_all_errors(save=True)
#
# TypeError: get_all_errors() missing 1 required positional argument: 'basemodel'
